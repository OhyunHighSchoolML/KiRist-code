# %%
# !git clone https://github.com/OhyunHighSchoolML/dosoung.git
# Out:
# fatal: destination path 'dosoung' already exists and is not an empty directory.

# %%
import pandas as pd
import numpy as np

# %%
train_df = pd.read_csv('/content/dosoung/train.csv')
test_df = pd.read_csv('/content/dosoung/test.csv')

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
train_df.describe()
# Out:
#        PassengerId    Survived      Pclass  ...       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  ...  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642  ...    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071  ...    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000  ...    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000  ...    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000  ...    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000  ...    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000  ...    8.000000    6.000000  512.329200
#
# [8 rows x 7 columns]

# %%
train_df.describe(include=['O'])
# Out:
#                              Name   Sex  Ticket        Cabin Embarked
# count                         891   891     891          204      889
# unique                        891     2     681          147        3
# top     Bostandyeff, Mr. Guentcho  male  347082  C23 C25 C27        S
# freq                            1   577       7            4      644

# %% [markdown]
# #데이터 분석

# %%
train_df[['Pclass','Survived']].groupby('Pclass').mean()
# Out:
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %%
train_df[['Sex','Survived']].groupby('Sex').mean()
# Out:
#         Survived
# Sex
# female  0.742038
# male    0.188908

# %%
train_df[['Embarked','Survived']].groupby('Embarked').mean()
# Out:
#           Survived
# Embarked
# C         0.553571
# Q         0.389610
# S         0.336957

# %%
train_df[['SibSp','Survived']].groupby('SibSp').mean()
# Out:
#        Survived
# SibSp
# 0      0.345395
# 1      0.535885
# 2      0.464286
# 3      0.250000
# 4      0.166667
# 5      0.000000
# 8      0.000000

# %% [markdown]
# #visualization data analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
plt.hist(train_df['Age'],bins=30)
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# (array([30., 14., 10., 14.,  3., 29., 39., 65., 73., 42., 65., 62., 33.,
#         47., 38., 21., 28., 21., 16., 14., 15.,  7.,  9.,  8.,  4.,  0.,
#          5.,  1.,  0.,  1.]),
#  array([ 0.42      ,  3.07266667,  5.72533333,  8.378     , 11.03066667,
#         13.68333333, 16.336     , 18.98866667, 21.64133333, 24.294     ,
#         26.94666667, 29.59933333, 32.252     , 34.90466667, 37.55733333,
#         40.21      , 42.86266667, 45.51533333, 48.168     , 50.82066667,
#         53.47333333, 56.126     , 58.77866667, 61.43133333, 64.084     ,
#         66.73666667, 69.38933333, 72.042     , 74.69466667, 77.34733333,
#         80.        ]),
#  <a list of 30 Patch objects>)

# %%
grid = sns.FacetGrid(train_df,col='Survived',hue='Survived')
grid.map(plt.hist,'Age',bins=20)

# %%
grid = sns.FacetGrid(train_df,row='Pclass',col='Survived')
grid.map(plt.hist,'Age',bins=20)

# %%
grid = sns.FacetGrid(train_df,row='Embarked')
grid.map(sns.pointplot,'Pclass','Survived','Sex')
grid.add_legend()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:723: UserWarning: Using the pointplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:728: UserWarning: Using the pointplot function without specifying `hue_order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
grid = sns.FacetGrid(train_df,row='Embarked',col='Survived')
grid.map(sns.barplot,'Sex','Fare')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:723: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
train_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
train_df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
combine = [train_df,test_df]

# %%
combine
# Out:
# [     PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
#  0              1         0       3  ...   7.2500   NaN         S
#  1              2         1       1  ...  71.2833   C85         C
#  2              3         1       3  ...   7.9250   NaN         S
#  3              4         1       1  ...  53.1000  C123         S
#  4              5         0       3  ...   8.0500   NaN         S
#  ..           ...       ...     ...  ...      ...   ...       ...
#  886          887         0       2  ...  13.0000   NaN         S
#  887          888         1       1  ...  30.0000   B42         S
#  888          889         0       3  ...  23.4500   NaN         S
#  889          890         1       1  ...  30.0000  C148         C
#  890          891         0       3  ...   7.7500   NaN         Q
#
#  [891 rows x 12 columns],      PassengerId  Pclass  ... Cabin Embarked
#  0            892       3  ...   NaN        Q
#  1            893       3  ...   NaN        S
#  2            894       2  ...   NaN        Q
#  3            895       3  ...   NaN        S
#  4            896       3  ...   NaN        S
#  ..           ...     ...  ...   ...      ...
#  413         1305       3  ...   NaN        S
#  414         1306       1  ...  C105        C
#  415         1307       3  ...   NaN        S
#  416         1308       3  ...   NaN        S
#  417         1309       3  ...   NaN        C
#
#  [418 rows x 11 columns]]

# %%
for dataset in combine:
  dataset['Title'] = dataset['Name'].str.extract(' ([A-Za-z]+)\. ',expand=False)

# %%
train_df['Title'].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Don', 'Rev', 'Dr', 'Mme', 'Ms',
#        'Major', 'Lady', 'Sir', 'Mlle', 'Col', 'Capt', 'Countess',
#        'Jonkheer'], dtype=object)

# %%
pd.crosstab(train_df['Title'],train_df['Sex'])
# Out:
# Sex       female  male
# Title
# Capt           0     1
# Col            0     2
# Countess       1     0
# Don            0     1
# Dr             1     6
# Jonkheer       0     1
# Lady           1     0
# Major          0     2
# Master         0    40
# Miss         182     0
# Mlle           2     0
# Mme            1     0
# Mr             0   517
# Mrs          125     0
# Ms             1     0
# Rev            0     6
# Sir            0     1

# %%
for dataset in combine:
  dataset['Title'] = dataset['Title'].replace(['Capt','Apt','Countess','Col','Don','Dr','Major','Rev','Sir','Jonkheer','Dona','Lady'], 'Other')
  dataset['Title'] = dataset['Title'].replace('Mlle','Miss')
  dataset['Title'] = dataset['Title'].replace('Ms','Miss')
  dataset['Title'] = dataset['Title'].replace('Mme','Mr')

# %%
train_df['Title'].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Other'], dtype=object)

# %%
train_df[['Title','Survived']].groupby('Title',as_index=False).mean()
# Out:
#     Title  Survived
# 0  Master  0.575000
# 1    Miss  0.702703
# 2      Mr  0.158301
# 3     Mrs  0.792000
# 4   Other  0.347826

# %%
train_df['Title']
# Out:
# 0         Mr
# 1        Mrs
# 2       Miss
# 3        Mrs
# 4         Mr
#        ...
# 886    Other
# 887     Miss
# 888     Miss
# 889       Mr
# 890       Mr
# Name: Title, Length: 891, dtype: object

# %%
title_column={'Mr':1,'Miss':2,'Mrs':3,'Master':4,'Other':5}
for dataset in combine:
  dataset['Title'] = dataset['Title'].map(title_column)
  dataset['Title'] = dataset['Title'].fillna(0)
  dataset['Title'] = dataset['Title'].astype(int)

# %%
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  ... Cabin Embarked  Title
# 0            1         0       3  ...   NaN        S      1
# 1            2         1       1  ...   C85        C      3
# 2            3         1       3  ...   NaN        S      2
# 3            4         1       1  ...  C123        S      3
# 4            5         0       3  ...   NaN        S      1
#
# [5 rows x 13 columns]

# %%
combine=[train_df,test_df]

# %%
for dataset in combine:
  dataset['Sex'] = dataset['Sex'].replace({'male': 0,'female': 1})

# %%
for dataset in combine:
  dataset['Age'].fillna(dataset['Age'].mean() , inplace=True)
  dataset['Age'] = dataset['Age'].astype(int)

# %%
train_df['Age'].isnull().sum()
# Out:
# 0

# %%
test_df.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# Title            0
# dtype: int64

# %%
train_df['Age'].unique()
# Out:
# array([22, 38, 26, 35, 29, 54,  2, 27, 14,  4, 58, 20, 39, 55, 31, 34, 15,
#        28,  8, 19, 40, 66, 42, 21, 18,  3,  7, 49, 65,  5, 11, 45, 17, 32,
#        16, 25,  0, 30, 33, 23, 24, 46, 59, 71, 37, 47, 70, 12,  9, 36, 51,
#        44,  1, 61, 56, 50, 62, 41, 52, 63, 43, 60, 10, 64, 13, 48, 53, 57,
#        80,  6, 74])

# %%
train_df['AgeBand'] = pd.cut(train_df['Age'],5) #cut은 동일한 길이로 나누기

# %%
train_df['AgeBand'].unique()
# Out:
# [(16.0, 32.0], (32.0, 48.0], (48.0, 64.0], (-0.08, 16.0], (64.0, 80.0]]
# Categories (5, interval[float64]): [(-0.08, 16.0] < (16.0, 32.0] < (32.0, 48.0] < (48.0, 64.0] <
#                                     (64.0, 80.0]]

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  ... Embarked  Title       AgeBand
# 0              1         0       3  ...        S      1  (16.0, 32.0]
# 1              2         1       1  ...        C      3  (32.0, 48.0]
# 2              3         1       3  ...        S      2  (16.0, 32.0]
# 3              4         1       1  ...        S      3  (32.0, 48.0]
# 4              5         0       3  ...        S      1  (32.0, 48.0]
# ..           ...       ...     ...  ...      ...    ...           ...
# 886          887         0       2  ...        S      5  (16.0, 32.0]
# 887          888         1       1  ...        S      2  (16.0, 32.0]
# 888          889         0       3  ...        S      2  (16.0, 32.0]
# 889          890         1       1  ...        C      1  (16.0, 32.0]
# 890          891         0       3  ...        Q      1  (16.0, 32.0]
#
# [891 rows x 14 columns]

# %%
for dataset in combine:
  dataset.loc[dataset['Age']<=16, 'Age;'] = 0
  dataset.loc[(dataset['Age'] > 16) & (dataset['Age'] <=32),'Age'] = 1
  dataset.loc[(dataset['Age'] > 32) & (dataset['Age'] <=48),'Age'] = 2
  dataset.loc[(dataset['Age'] > 48) & (dataset['Age'] <=64),'Age'] = 3
  dataset.loc[(dataset['Age'] > 64),'Age'] = 4

# %%
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  ... Title       AgeBand  Age;
# 0            1         0       3  ...     1  (16.0, 32.0]   NaN
# 1            2         1       1  ...     3  (32.0, 48.0]   NaN
# 2            3         1       3  ...     2  (16.0, 32.0]   NaN
# 3            4         1       1  ...     3  (32.0, 48.0]   NaN
# 4            5         0       3  ...     1  (32.0, 48.0]   NaN
#
# [5 rows x 15 columns]

# %%
train_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# Title            0
# AgeBand          0
# Age;           791
# dtype: int64

# %%
train_df[train_df['Embarked'].isnull()]
# Out:
#      PassengerId  Survived  Pclass  ... Title       AgeBand  Age;
# 61            62         1       1  ...     2  (32.0, 48.0]   NaN
# 829          830         1       1  ...     3  (48.0, 64.0]   NaN
#
# [2 rows x 15 columns]

# %%
train_df[(train_df['Pclass'] == 1) &  (train_df['Survived'] == 1) ]['Embarked'].value_counts()
# Out:
# S    74
# C    59
# Q     1
# Name: Embarked, dtype: int64

# %%
train_df['Embarked'] = train_df['Embarked'].fillna('S')

# %%
train_df['Embarked'] = train_df['Embarked'].astype(str)

# %%
train_df.dtypes
# Out:
# PassengerId       int64
# Survived          int64
# Pclass            int64
# Name             object
# Sex               int64
# Age               int64
# SibSp             int64
# Parch             int64
# Ticket           object
# Fare            float64
# Cabin            object
# Embarked         object
# Title             int64
# AgeBand        category
# Age;            float64
# dtype: object

# %%
for dataset in combine:
  dataset['Embarked'] = dataset['Embarked'].map({'S':0,'C':1,'Q':2})

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  ... Title       AgeBand  Age;
# 0              1         0       3  ...     1  (16.0, 32.0]   NaN
# 1              2         1       1  ...     3  (32.0, 48.0]   NaN
# 2              3         1       3  ...     2  (16.0, 32.0]   NaN
# 3              4         1       1  ...     3  (32.0, 48.0]   NaN
# 4              5         0       3  ...     1  (32.0, 48.0]   NaN
# ..           ...       ...     ...  ...   ...           ...   ...
# 886          887         0       2  ...     5  (16.0, 32.0]   NaN
# 887          888         1       1  ...     2  (16.0, 32.0]   NaN
# 888          889         0       3  ...     2  (16.0, 32.0]   NaN
# 889          890         1       1  ...     1  (16.0, 32.0]   NaN
# 890          891         0       3  ...     1  (16.0, 32.0]   NaN
#
# [891 rows x 15 columns]

# %%
test_df.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# Title            0
# Age;           384
# dtype: int64

# %%
test_df[test_df['Fare'].isnull()]
# Out:
#      PassengerId  Pclass                Name  Sex  ...  Cabin  Embarked  Title Age;
# 152         1044       3  Storey, Mr. Thomas    0  ...    NaN         0      1  NaN
#
# [1 rows x 13 columns]

# %%
test_df[test_df['Fare'].isnull()] = test_df[test_df['Pclass'] == 3]['Fare'].mean()

# %%
train_df['FareBand'] = pd.qcut(train_df['Fare'],4) #pd.qcut은 동일한 값으로 나누기
train_df[['FareBand','Survived']].groupby('FareBand',as_index=False).mean()
# Out:
#           FareBand  Survived
# 0   (-0.001, 7.91]  0.197309
# 1   (7.91, 14.454]  0.303571
# 2   (14.454, 31.0]  0.454955
# 3  (31.0, 512.329]  0.581081

# %%
for dataset in combine:
  dataset.loc[dataset['Fare']<=7.91, 'Fare'] = 0
  dataset.loc[(dataset['Fare'] > 7.91) & (dataset['Fare'] <=14.454),'Fare'] = 1
  dataset.loc[(dataset['Fare'] > 14.454) & (dataset['Fare'] <=31),'Fare'] = 2
  dataset.loc[(dataset['Fare'] > 31) & (dataset['Fare']),'Fare']= 3

# %%
test_df['Fare'].fillna(12.459678,inplace=True)

# %%
for dataset in combine:
  dataset['Fare'] = dataset['Fare'].astype(int)

# %%
for dataset in combine:
  dataset['Family'] = dataset['SibSp']+dataset['Parch']
  dataset['Family'] = dataset['Family'].astype(int)

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  ... Age;         FareBand  Family
# 0              1         0       3  ...  NaN   (-0.001, 7.91]       1
# 1              2         1       1  ...  NaN  (31.0, 512.329]       1
# 2              3         1       3  ...  NaN   (7.91, 14.454]       0
# 3              4         1       1  ...  NaN  (31.0, 512.329]       1
# 4              5         0       3  ...  NaN   (7.91, 14.454]       0
# ..           ...       ...     ...  ...  ...              ...     ...
# 886          887         0       2  ...  NaN   (7.91, 14.454]       0
# 887          888         1       1  ...  NaN   (14.454, 31.0]       0
# 888          889         0       3  ...  NaN   (14.454, 31.0]       3
# 889          890         1       1  ...  NaN   (14.454, 31.0]       0
# 890          891         0       3  ...  NaN   (-0.001, 7.91]       0
#
# [891 rows x 17 columns]

# %%
train_df.drop(['AgeBand','FareBand','SibSp','Parch','Name','Ticket','Cabin'], axis=1, inplace=True)

# %%
train_df.drop(['Age;'], axis=1, inplace=True)

# %%
test_df.drop(['SibSp','Parch','Name','Ticket','Cabin'], axis=1, inplace=True)

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  Sex  Age  Fare  Embarked  Title  Family
# 0              1         0       3    0    1     0         0      1       1
# 1              2         1       1    1    2     3         1      3       1
# 2              3         1       3    1    1     1         0      2       0
# 3              4         1       1    1    2     3         0      3       1
# 4              5         0       3    0    2     1         0      1       0
# ..           ...       ...     ...  ...  ...   ...       ...    ...     ...
# 886          887         0       2    0    1     1         0      5       0
# 887          888         1       1    1    1     2         0      2       0
# 888          889         0       3    1    1     2         0      2       3
# 889          890         1       1    0    1     2         1      1       0
# 890          891         0       3    0    1     0         2      1       0
#
# [891 rows x 9 columns]

# %%
X_train = train_df.drop('Survived',axis=1)
y_train = train_df['Survived']
X_test = test_df

# %%
X_train.shape, y_train.shape, X_test.shape
# Out:
# ((891, 7), (891,), (418, 7))

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB

from sklearn.utils import shuffle

# %%
X_train, y_train = shuffle(X_train,y_train,random_state = 23)

# %%
def train_and_test(model):
  model.fit(X_train,y_train)
  pred = model.predict(X_test)
  accuracy = round(model.score(X_train,y_train) * 100,2)
  print('Accuracy: ', accuracy)
  return pred, accuracy

# %%
train_df.drop(['PassengerId'],axis=1,inplace=True)

# %%
test_df.drop(['PassengerId','Age;'],axis=1,inplace=True)

# %%
test_df
# Out:
#      Pclass  Sex  Age  Fare  Embarked  Title  Family
# 0       3.0  0.0  2.0     0       2.0    1.0       0
# 1       3.0  1.0  2.0     0       0.0    3.0       1
# 2       2.0  0.0  3.0     1       2.0    1.0       0
# 3       3.0  0.0  1.0     1       0.0    1.0       0
# 4       3.0  1.0  1.0     1       0.0    3.0       2
# ..      ...  ...  ...   ...       ...    ...     ...
# 413     3.0  0.0  1.0     1       0.0    1.0       0
# 414     1.0  1.0  2.0     3       1.0    5.0       0
# 415     3.0  0.0  2.0     0       0.0    1.0       0
# 416     3.0  0.0  1.0     1       0.0    1.0       0
# 417     3.0  0.0  1.0     2       1.0    4.0       2
#
# [418 rows x 7 columns]

# %%
log_pred,log_acc = train_and_test(LogisticRegression())
svm_pred, svm_acc = train_and_test(SVC())
rf_pred, rf_acc = train_and_test(RandomForestClassifier())
nb_pred, nb_acc = train_and_test(GaussianNB())
k_pred, k_acc = train_and_test(KNeighborsClassifier())
# Out:
# Accuracy:  79.8
# Accuracy:  83.39
# Accuracy:  89.34
# Accuracy:  80.47
# Accuracy:  85.75
