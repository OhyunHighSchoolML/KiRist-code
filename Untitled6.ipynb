# %%
import os
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen
from urllib.parse import quote_plus

def image_down(crawl_num, plusUrl):

    baseUrl = 'https://search.naver.com/search.naver?where=image&sm=tab_jum&query='
    url = baseUrl + quote_plus(plusUrl)
    html = urlopen(url)
    soup = bs(html, "html.parser")
    img = soup.find_all(class_='_img')
    n=1
    path = './'+plusUrl
    os.makedirs(path, exist_ok=True)
    for i in img:
        print(n,"번째 이미지 다운로드")
        imgUrl = i['data-source']
        with urlopen(imgUrl) as f:
            with open(path+'/' + str(n)+'.jpg','wb') as h:
                img = f.read()
                h.write(img)
        n += 1
        if n > crawl_num:
            break

image_down(50,"고양이")
# Out:
# 1 번째 이미지 다운로드
# 2 번째 이미지 다운로드
# 3 번째 이미지 다운로드
# 4 번째 이미지 다운로드
# 5 번째 이미지 다운로드
# 6 번째 이미지 다운로드
# 7 번째 이미지 다운로드
# 8 번째 이미지 다운로드
# 9 번째 이미지 다운로드
# 10 번째 이미지 다운로드
# 11 번째 이미지 다운로드
# 12 번째 이미지 다운로드
# 13 번째 이미지 다운로드
# 14 번째 이미지 다운로드
# 15 번째 이미지 다운로드
# 16 번째 이미지 다운로드
# 17 번째 이미지 다운로드
# 18 번째 이미지 다운로드
# 19 번째 이미지 다운로드
# 20 번째 이미지 다운로드
# 21 번째 이미지 다운로드
# 22 번째 이미지 다운로드
# 23 번째 이미지 다운로드
# 24 번째 이미지 다운로드
# 25 번째 이미지 다운로드
# 26 번째 이미지 다운로드
# 27 번째 이미지 다운로드
# 28 번째 이미지 다운로드
# 29 번째 이미지 다운로드
# 30 번째 이미지 다운로드
# 31 번째 이미지 다운로드
# 32 번째 이미지 다운로드
# 33 번째 이미지 다운로드
# 34 번째 이미지 다운로드
# 35 번째 이미지 다운로드
# 36 번째 이미지 다운로드
# 37 번째 이미지 다운로드
# 38 번째 이미지 다운로드
# 39 번째 이미지 다운로드
# 40 번째 이미지 다운로드
# 41 번째 이미지 다운로드
# 42 번째 이미지 다운로드
# 43 번째 이미지 다운로드
# 44 번째 이미지 다운로드
# 45 번째 이미지 다운로드
# 46 번째 이미지 다운로드
# 47 번째 이미지 다운로드
# 48 번째 이미지 다운로드
# 49 번째 이미지 다운로드
# 50 번째 이미지 다운로드

# %%
import tensorflow as tf

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2
from PIL import Image
# %matplotlib inline

# %%
import seaborn as sns

# %%
def load_dog_cat_data(data_dir, width=300, height=300):
    x_data = []
    y_data = []
    for i in os.listdir('/content/고양이'):
        file_path = '/content/고양이/{}'.format(i)
        image_numpy = convert_color_image_to_numpy(file_path, width, height)    
        x_data.append(image_numpy)
        y_data.append('cat')
    x_data = np.array(x_data)
    y_data = np.array(y_data)

    return x_data, y_data

# %%
def convert_color_image_to_numpy(file_path, width=300, height=300):
    if type(file_path) == str:
        image = Image.open(file_path)
    else:
        image = file_path
    image = image.convert('RGB')
    if width != None and height != None:
        image = image.resize((width, height))    
    image_numpy = np.array(image) #이미지 타입을 넘파이 타입으로 변환

    return image_numpy

# %%
width = 300
height = 300
color = 3
x_data, y_data = load_dog_cat_data('/content/고양이')

# %%
len(x_data)
# Out:
# 50

# %%
plt.imshow(x_data[1])

# %%
def show_num(img, tag):
    plt.imshow(img)
    plt.xticks([])
    plt.yticks([])
    plt.xlabel('tag : '+str(tag), size=40)
    plt.show()

# %%
show_num(x_data[1],y_data[0])

# %%
print(len(x_data))
# Out:
# 50

# %%
x_data[0].max
# Out:
# <function ndarray.max>

# %%
x_data
# Out:
# array([[[[174, 174, 174],
#          [185, 185, 185],
#          [184, 184, 184],
#          ...,
#          [184, 184, 182],
#          [185, 185, 183],
#          [174, 174, 172]],
#
#         [[191, 191, 191],
#          [245, 245, 245],
#          [251, 251, 251],
#          ...,
#          [251, 251, 249],
#          [245, 245, 243],
#          [191, 191, 189]],
#
#         [[193, 194, 193],
#          [253, 253, 253],
#          [253, 253, 253],
#          ...,
#          [253, 253, 251],
#          [253, 253, 251],
#          [193, 193, 191]],
#
#         ...,
#
#         [[196, 196, 196],
#          [254, 254, 254],
#          [254, 254, 254],
#          ...,
#          [254, 254, 254],
#          [254, 254, 254],
#          [196, 196, 196]],
#
#         [[191, 191, 191],
#          [249, 249, 249],
#          [250, 250, 250],
#          ...,
#          [250, 250, 250],
#          [249, 249, 249],
#          [191, 191, 191]],
#
#         [[174, 174, 174],
# ...

# %%
x_data[0].max()
# Out:
# 255

# %%
x_data[0].min()
# Out:
# 0
